# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([[151], [174], [138], [186], [128], [136], [179], [163], [152], [131]])
y = np.array([63, 81, 56, 91, 47, 57, 76, 72, 62, 48])

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x, y)
# Out:
# LinearRegression()

# %%
plt.xlabel('Height')
plt.ylabel('Weight')
plt.scatter(x, y);

# %%
regressor.predict([[185]]) # the val which are not present in dataset & also they gives the weight
# Out:
# array([86.34784601])

# %%
regressor.predict([[169]])
# Out:
# array([75.55407883])

# %%
regressor.predict([[144]])
# Out:
# array([58.6888176])

# %%
y_pred = regressor.predict(x)

# %%
plt.xlabel('Height')
plt.ylabel('Weight')
plt.scatter(x, y, color = 'r')
plt.plot(x, y_pred, color = 'b');

# %%
regressor.score(x, y) #Accuracy
# Out:
# 0.9547822477500306
